# %%
import pandas as pd

# %%
df = pd.read_csv("caravan.csv", index_col=0)

# %%
df
# Out:
#       MOSTYPE  MAANTHUI  MGEMOMV  MGEMLEEF  MOSHOOFD  MGODRK  MGODPR  MGODOV  \
# 1          33         1        3         2         8       0       5       1
# 2          37         1        2         2         8       1       4       1
# 3          37         1        2         2         8       0       4       2
# 4           9         1        3         3         3       2       3       2
# 5          40         1        4         2        10       1       4       1
# ...       ...       ...      ...       ...       ...     ...     ...     ...
# 5818       36         1        1         2         8       0       6       1
# 5819       35         1        4         4         8       1       4       1
# 5820       33         1        3         4         8       0       6       0
# 5821       34         1        3         2         8       0       7       0
# 5822       33         1        3         3         8       0       6       1
#
# ...

# %%
df['Purchase']= df.Purchase.eq('Yes').mul(1)

# %%
test = df[:1000]
train = df[1000:]
