# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale
import sys
from sklearn import linear_model

# %%
boston = load_boston()
Boston = pd.DataFrame(data = boston.data, columns=boston.feature_names)

# %%
Boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
X, y = load_boston(return_X_y=True)
iLog = [0,2,4,5,7,8,9]
for i in iLog:
    X[:,i] = np.log(X[:,i])
y = np.log(y)
X[:,1] = X[:,1]/10
X[:, 6] = np.power(X[:, 6],2.5) / 10000
X[:, 10] = np.exp(0.4 * X[:, 10]) / 1000
X[:, 11] = X[:, 11] / 100
X[:, 12] = np.sqrt(X[:, 12])
lam_seq = [0.30, 0.2, 0.1, 0.05, 0.02, 0.005]

# %%
def one_var_lasso(r, x, lam):
    xx = np.sum(x**2)
    xr = np.sum(r * x)
    b = (np.abs(xr) - lam/2)/xx
    if b > 0:
        b = b * np.sign(xr)
    else:
        b = 0
    return(b)

# %%
def MyLasso(X, y, lam_seq, maxit = 50):
    
    n = len(y)
    p = X.shape[1]
    nlam = len(lam_seq)
    
    
    #mean and scale
    y_mean = np.nanmean(y)
    
    
    X_mean = np.nanmean(X, axis=0)
    X_sd = np.nanstd(X, axis=0)
    
    
    Xs = np.zeros(shape = X.shape)
    for i in range(0,X.shape[1]):
        Xs[:,i] =  (X[:,i] - X_mean[i])/X_sd[i]
    
    yc = y - y_mean
    
    
    
    
    #return mean_
    
    b = np.zeros(p)
    r = yc
    B = np.zeros(shape = (nlam,p+1))
    
    for m in range(0,nlam):
        lam = 2 * n * lam_seq[m]
        for step in range(0,maxit):
            for j in range(0,p):
                r = r + (Xs[:,j] * b[j])
                b[j] = one_var_lasso(r, Xs[:, j], lam)
                r = r - Xs[:, j] * b[j]
        B[m,1:] = b
        
    #get intercepts
    
    
    for i in range(0,6):
        bjx =  0
        for j in range (1,14):
            bjx += B[i,j] * (X_mean[j-1]/X_sd[j-1])
        B[i,0] = y_mean - bjx
        
    
    return B

# %%
myout = MyLasso(X, y, lam_seq, maxit = 50)
myout = myout.transpose()

# %%
df = pd.read_csv('Coef_Lasso.dat')

# %%
df
# Out:
#                    s0        s1        s2        s3        s4        s5
# (Intercept)  3.162393  3.508946  3.855936  3.778456  3.542129  3.925458
# crim         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# zn           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# indus        0.000000  0.000000  0.000000  0.000000  0.000000 -0.005399
# chas         0.000000  0.000000  0.000000  0.000000  0.066692  0.099120
# nox          0.000000  0.000000  0.000000  0.000000  0.000000 -0.125163
# rm           0.000000  0.000000  0.000000  0.240416  0.417249  0.459273
# age          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# dis          0.000000  0.000000  0.000000  0.000000 -0.004681 -0.120438
# rad          0.000000  0.000000  0.000000  0.000000  0.000000  0.014980
# tax          0.000000  0.000000  0.000000 -0.055309 -0.080579 -0.149039
# ptratio      0.000000  0.000000 -0.004310 -0.023648 -0.033627 -0.038211
# black        0.000000  0.000000  0.000000  0.008515  0.031234  0.043402
# lstat       -0.037417 -0.138818 -0.237634 -0.244558 -0.243490 -0.256709

# %%
df2 = pd.DataFrame(data=myout)
df2
# Out:
#            0         1         2         3         4         5
# 0   3.162393  3.508946  3.855935  3.777920  3.541573  3.927046
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000 -0.004095
# 4   0.000000  0.000000  0.000000  0.000000  0.016917  0.025133
# 5   0.000000  0.000000  0.000000  0.000000  0.000000 -0.024858
# 6   0.000000  0.000000  0.000000  0.027013  0.046862  0.051582
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000 -0.002526 -0.064578
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.013213
# 10  0.000000  0.000000  0.000000 -0.021912 -0.031929 -0.059203
# 11  0.000000  0.000000 -0.005864 -0.032222 -0.045838 -0.052100
# 12  0.000000  0.000000  0.000000  0.007773  0.028506  0.039630
# 13 -0.036901 -0.136901 -0.234357 -0.241152 -0.240078 -0.253138

# %%
lasso_fit = df.to_numpy()

# %%
np.max(np.abs(lasso_fit - myout))
# Out:
# 0.40769004598781744

# %%
clf = linear_model.Lasso(alpha=0.02, max_iter = 50)
clf.fit(X,y)
print(clf.coef_)
# Out:
# [-0.01126099 -0.         -0.          0.         -0.          0.
#   0.00679794 -0.         -0.         -0.         -0.04733749  0.02539355
#  -0.2845004 ]
