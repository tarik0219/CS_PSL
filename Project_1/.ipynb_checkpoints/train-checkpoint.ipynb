# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#             PID                          MS_SubClass                MS_Zoning  \
# 0     526301100  One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 1     526351010  One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 2     526353030  One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 3     527105010             Two_Story_1946_and_Newer  Residential_Low_Density
# 4     527145080         One_Story_PUD_1946_and_Newer  Residential_Low_Density
# ...         ...                                  ...                      ...
# 2046  923251180  One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 2047  923275080                  Split_or_Multilevel  Residential_Low_Density
# 2048  923276100  One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 2049  923400125                          Split_Foyer  Residential_Low_Density
# 2050  924151050             Two_Story_1946_and_Newer  Residential_Low_Density
#
#       Lot_Frontage  Lot_Area Street            Alley           Lot_Shape  \
# 0              141     31770   Pave  No_Alley_Access  Slightly_Irregular
# 1               81     14267   Pave  No_Alley_Access  Slightly_Irregular
# 2               93     11160   Pave  No_Alley_Access             Regular
# 3               74     13830   Pave  No_Alley_Access  Slightly_Irregular
# 4               43      5005   Pave  No_Alley_Access  Slightly_Irregular
# ...            ...       ...    ...              ...                 ...
# 2046           160     20000   Pave  No_Alley_Access             Regular
# 2047            37      7937   Pave  No_Alley_Access  Slightly_Irregular
# 2048             0      8885   Pave  No_Alley_Access  Slightly_Irregular
# 2049            62     10441   Pave  No_Alley_Access             Regular
# 2050            74      9627   Pave  No_Alley_Access             Regular
#
#      Land_Contour Utilities  ...            Fence Misc_Feature Misc_Val  \
# 0             Lvl    AllPub  ...         No_Fence         None        0
# 1             Lvl    AllPub  ...         No_Fence         Gar2    12500
# 2             Lvl    AllPub  ...         No_Fence         None        0
# 3             Lvl    AllPub  ...  Minimum_Privacy         None        0
# 4             HLS    AllPub  ...         No_Fence         None        0
# ...           ...       ...  ...              ...          ...      ...
# 2046          Lvl    AllPub  ...         No_Fence         None        0
# 2047          Lvl    AllPub  ...     Good_Privacy         None        0
# 2048          Low    AllPub  ...  Minimum_Privacy         None        0
# 2049          Lvl    AllPub  ...  Minimum_Privacy         Shed      700
# 2050          Lvl    AllPub  ...         No_Fence         None        0
#
#      Mo_Sold Year_Sold Sale_Type Sale_Condition  Longitude   Latitude  \
# 0          5      2010       WD          Normal -93.619754  42.054035
# 1          6      2010       WD          Normal -93.619387  42.052659
# 2          4      2010       WD          Normal -93.617320  42.051245
# 3          3      2010       WD          Normal -93.638933  42.060899
# 4          1      2010       WD          Normal -93.633826  42.060728
# ...      ...       ...       ...            ...        ...        ...
# 2046       9      2006       WD         Abnorml -93.606842  41.987686
# 2047       3      2006       WD          Normal -93.604776  41.988964
# 2048       6      2006       WD          Normal -93.602680  41.988314
# 2049       7      2006       WD          Normal -93.606847  41.986510
# 2050      11      2006       WD          Normal -93.599996  41.989265
#
#       Sale_Price
# 0         215000
# 1         172000
# 2         244000
# 3         189900
# 4         191500
# ...          ...
# 2046      131000
# 2047      142500
# 2048      131000
# 2049      132000
# 2050      188000
#
# [2051 rows x 83 columns]

# %%
OneHotEncoder().fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ce6e9c471b0f> in <module>
# ----> 1 OneHotEncoder().fit_transform(df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     370         """
#     371         self._validate_keywords()
# --> 372         return super().fit_transform(X, y)
#     373
#     374     def transform(self, X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     345         """
#     346         self._validate_keywords()
# --> 347         self._fit(X, handle_unknown=self.handle_unknown)
#     348         self.drop_idx_ = self._compute_drop_idx()
#     349         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in _fit(self, X, handle_unknown)
#      72
#      73     def _fit(self, X, handle_unknown='error'):
# ---> 74         X_list, n_samples, n_features = self._check_X(X)
#      75
#      76         if self.categories != 'auto':
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in _check_X(self, X)
#      59             Xi = self._get_feature(X, feature_idx=i)
#      60             Xi = check_array(Xi, ensure_2d=False, dtype=None,
# ---> 61                              force_all_finite=needs_validation)
#      62             X_columns.append(Xi)
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
df = df.drop(['PID'], axis=1)

# %%
df
# Out:
#                               MS_SubClass                MS_Zoning  \
# 0     One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 1     One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 2     One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 3                Two_Story_1946_and_Newer  Residential_Low_Density
# 4            One_Story_PUD_1946_and_Newer  Residential_Low_Density
# ...                                   ...                      ...
# 2046  One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 2047                  Split_or_Multilevel  Residential_Low_Density
# 2048  One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# 2049                          Split_Foyer  Residential_Low_Density
# 2050             Two_Story_1946_and_Newer  Residential_Low_Density
#
#       Lot_Frontage  Lot_Area Street            Alley           Lot_Shape  \
# 0              141     31770   Pave  No_Alley_Access  Slightly_Irregular
# 1               81     14267   Pave  No_Alley_Access  Slightly_Irregular
# 2               93     11160   Pave  No_Alley_Access             Regular
# 3               74     13830   Pave  No_Alley_Access  Slightly_Irregular
# 4               43      5005   Pave  No_Alley_Access  Slightly_Irregular
# ...            ...       ...    ...              ...                 ...
# 2046           160     20000   Pave  No_Alley_Access             Regular
# 2047            37      7937   Pave  No_Alley_Access  Slightly_Irregular
# 2048             0      8885   Pave  No_Alley_Access  Slightly_Irregular
# 2049            62     10441   Pave  No_Alley_Access             Regular
# 2050            74      9627   Pave  No_Alley_Access             Regular
#
#      Land_Contour Utilities Lot_Config  ...            Fence Misc_Feature  \
# 0             Lvl    AllPub     Corner  ...         No_Fence         None
# 1             Lvl    AllPub     Corner  ...         No_Fence         Gar2
# 2             Lvl    AllPub     Corner  ...         No_Fence         None
# 3             Lvl    AllPub     Inside  ...  Minimum_Privacy         None
# 4             HLS    AllPub     Inside  ...         No_Fence         None
# ...           ...       ...        ...  ...              ...          ...
# 2046          Lvl    AllPub     Inside  ...         No_Fence         None
# 2047          Lvl    AllPub    CulDSac  ...     Good_Privacy         None
# 2048          Low    AllPub     Inside  ...  Minimum_Privacy         None
# 2049          Lvl    AllPub     Inside  ...  Minimum_Privacy         Shed
# 2050          Lvl    AllPub     Inside  ...         No_Fence         None
#
#      Misc_Val Mo_Sold Year_Sold Sale_Type Sale_Condition  Longitude  \
# 0           0       5      2010       WD          Normal -93.619754
# 1       12500       6      2010       WD          Normal -93.619387
# 2           0       4      2010       WD          Normal -93.617320
# 3           0       3      2010       WD          Normal -93.638933
# 4           0       1      2010       WD          Normal -93.633826
# ...       ...     ...       ...       ...            ...        ...
# 2046        0       9      2006       WD         Abnorml -93.606842
# 2047        0       3      2006       WD          Normal -93.604776
# 2048        0       6      2006       WD          Normal -93.602680
# 2049      700       7      2006       WD          Normal -93.606847
# 2050        0      11      2006       WD          Normal -93.599996
#
#        Latitude  Sale_Price
# 0     42.054035      215000
# 1     42.052659      172000
# 2     42.051245      244000
# 3     42.060899      189900
# 4     42.060728      191500
# ...         ...         ...
# 2046  41.987686      131000
# 2047  41.988964      142500
# 2048  41.988314      131000
# 2049  41.986510      132000
# 2050  41.989265      188000
#
# [2051 rows x 82 columns]

# %%
columns = df.columns.to_list()
columns.pop()
X = df[['Lot_Frontage', 'Lot_Area', 'Street', 'Alley', ]].values
y = df[['Sale_Price']].values

# %%
X
# Out:
# array([['One_Story_1946_and_Newer_All_Styles', 'Residential_Low_Density',
#         141, ..., 'Normal', -93.619754, 42.054035],
#        ['One_Story_1946_and_Newer_All_Styles', 'Residential_Low_Density',
#         81, ..., 'Normal', -93.6193873, 42.052659000000006],
#        ['One_Story_1946_and_Newer_All_Styles', 'Residential_Low_Density',
#         93, ..., 'Normal', -93.61731999999999, 42.051245],
#        ...,
#        ['One_Story_1946_and_Newer_All_Styles', 'Residential_Low_Density',
#         0, ..., 'Normal', -93.60268, 41.988314],
#        ['Split_Foyer', 'Residential_Low_Density', 62, ..., 'Normal',
#         -93.606847, 41.986509999999996],
#        ['Two_Story_1946_and_Newer', 'Residential_Low_Density', 74, ...,
#         'Normal', -93.59999599999999, 41.989265]], dtype=object)
